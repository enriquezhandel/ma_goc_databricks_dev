# %%
import dlt
from pyspark.sql.types import DateType, IntegerType,LongType, StructType, StructField, TimestampType, StringType, BooleanType, DoubleType
from pyspark.sql.functions import col

# %%
@dlt.table(
    comment="This is just a view of the information to be used in the dashboard",
    name="Raw_Countries_and_Continents"
)
def Raw_IPDatasets():
    path = "/Volumes/ds_goc_volumes_dev/external_data/ma-ds-goc-prd-prod-storage-layer-eu-central-1/raw_goc_nosara_lkh/Countries_and_Continents/*"
    schema = StructType([
        StructField("Full_Name", StringType(), True),
        StructField("Name", StringType(), True),
        StructField("Asset_Id", StringType(), True),
        StructField("Asset_Type_Color", StringType(), True),
        StructField("Asset_Type_SymbolType", StringType(), True),
        StructField("Asset_Type_IconCode", DoubleType(), True),
        StructField("Asset_Type_AcronymCode", DoubleType(), True),
        StructField("Asset_Type_Display_Name_Enabled", BooleanType(), True),
        StructField("Domain", StringType(), True),
        StructField("Domain_Id", StringType(), True),
        StructField("[Geographic_Asset]_has_ISO_[Code_Value]_>_Name", StringType(), True),
        StructField("[Geographic_Asset]_has_ISO_[Code_Value]_>_Full_Name", StringType(), True),
        StructField("[Geographic_Asset]_has_ISO_[Code_Value]_>_Asset_Id", StringType(), True),
        StructField("SourceRelation_01910428-5cc8-7375-aa52-eb7381831832_Id", StringType(), True),
        StructField("Description", DoubleType(), True),
        StructField("Description_Id", DoubleType(), True),
        StructField("Note", DoubleType(), True),
        StructField("Note_Id", DoubleType(), True),
        StructField("Asset_Type", StringType(), True),
        StructField("Asset_Type_Discriminator", StringType(), True),
        StructField("Asset_Type_Is_System", BooleanType(), True),
        StructField("Asset_Type_Id", StringType(), True),
        StructField("Asset_Type_Public_Id", StringType(), True),
        StructField("Asset_Type_Final_Type", BooleanType(), True),
        StructField("Asset_Type_Lock_Statuses", BooleanType(), True),
        StructField("Asset_Type_Product", StringType(), True),
        StructField("[Geographic_Asset]_geographic_data_provided_by_[Vendor]_>_Name", StringType(), True),
        StructField("[Geographic_Asset]_geographic_data_provided_by_[Vendor]_>_Full_Name", StringType(), True),
        StructField("[Geographic_Asset]_geographic_data_provided_by_[Vendor]_>_Asset_Id", StringType(), True),
        StructField("TargetRelation_0191042a-d029-7597-bd96-78be271c6b80_Id", StringType(), True),
        StructField("[Geographic_Asset]_data_contained_in__[Product]_>_Name", StringType(), True),
        StructField("[Geographic_Asset]_data_contained_in__[Product]_>_Full_Name", StringType(), True),
        StructField("[Geographic_Asset]_data_contained_in__[Product]_>_Asset_Id", StringType(), True),
        StructField("TargetRelation_019104ae-c2cf-75dc-a54d-c0f646956f6e_Id", StringType(), True),
        StructField("[Geographic_Asset]_data_contained_in_[Fourth-Party_Data_Asset]_>_Name", StringType(), True),
        StructField("[Geographic_Asset]_data_contained_in_[Fourth-Party_Data_Asset]_>_Full_Name", StringType(), True),
        StructField("[Geographic_Asset]_data_contained_in_[Fourth-Party_Data_Asset]_>_Asset_Id", StringType(), True),
        StructField("TargetRelation_019104e0-8f88-7c73-ab76-f20e01b77e41_Id", StringType(), True),
        StructField("[Geographic_Asset]_is_a_location_of_[Fourth-Party_Vendor]_>_Name", StringType(), True),
        StructField("[Geographic_Asset]_is_a_location_of_[Fourth-Party_Vendor]_>_Full_Name", StringType(), True),
        StructField("[Geographic_Asset]_is_a_location_of_[Fourth-Party_Vendor]_>_Asset_Id", StringType(), True),
        StructField("SourceRelation_01922e57-da38-70b5-9c9f-40414d452352_Id", StringType(), True),
        StructField("Country_Data_Overview", DoubleType(), True),
        StructField("Country_Data_Overview_Id", DoubleType(), True),
        StructField("Additional_Considerations", StringType(), True),
        StructField("Additional_Considerations_Id", StringType(), True),
        StructField("Market_Coverage", DoubleType(), True),
        StructField("Market_Coverage_Id", DoubleType(), True),
        StructField("Filing_Requirements", StringType(), True),
        StructField("Filing_Requirements_Id", StringType(), True),
        StructField("[Geographic_Asset]_main_official_source_of_company_information_[Fourth-Party_Vendor]_>_Name", StringType(), True),
        StructField("[Geographic_Asset]_main_official_source_of_company_information_[Fourth-Party_Vendor]_>_Full_Name", StringType(), True),
        StructField("[Geographic_Asset]_main_official_source_of_company_information_[Fourth-Party_Vendor]_>_Asset_Id", StringType(), True),
        StructField("SourceRelation_0192b4b2-2442-723a-9c30-c9ec6579f796_Id", StringType(), True),
        StructField("[Geographic_Asset]_main_provider_of_country_data_is_[Vendor]_>_Name", StringType(), True),
        StructField("[Geographic_Asset]_main_provider_of_country_data_is_[Vendor]_>_Full_Name", StringType(), True),
        StructField("[Geographic_Asset]_main_provider_of_country_data_is_[Vendor]_>_Asset_Id", StringType(), True),
        StructField("TargetRelation_01910e25-7339-7525-a092-3889d1cd7f99_Id", StringType(), True),
        StructField("[Geographic_Asset]_main_provider_of_private_company_information_is_[Vendor]_>_Name", DoubleType(), True),
        StructField("[Geographic_Asset]_main_provider_of_private_company_information_is_[Vendor]_>_Full_Name", DoubleType(), True),
        StructField("[Geographic_Asset]_main_provider_of_private_company_information_is_[Vendor]_>_Asset_Id", DoubleType(), True),
        StructField("TargetRelation_01910e28-286f-7001-87ac-27877678ae5a_Id", DoubleType(), True),
        StructField("Number_of_Regions", DoubleType(), True),
        StructField("Number_of_Regions_Id", DoubleType(), True),
        StructField("Region_Code", StringType(), True),
        StructField("Region_Code_Id", StringType(), True),
        StructField("[Geographic_Asset]_groups_[Geographic_Asset]_>_Name", DoubleType(), True),
        StructField("[Geographic_Asset]_groups_[Geographic_Asset]_>_Full_Name", DoubleType(), True),
        StructField("[Geographic_Asset]_groups_[Geographic_Asset]_>_Asset_Id", DoubleType(), True),
        StructField("SourceRelation_0191991e-6173-7c97-96f0-5990682ca12a_Id", DoubleType(), True),
        StructField("[Geographic_Asset]_is_grouped_within_[Geographic_Asset]_>_Name", DoubleType(), True),
        StructField("[Geographic_Asset]_is_grouped_within_[Geographic_Asset]_>_Full_Name", DoubleType(), True),
        StructField("[Geographic_Asset]_is_grouped_within_[Geographic_Asset]_>_Asset_Id", DoubleType(), True),
        StructField("TargetRelation_0191991e-6173-7c97-96f0-5990682ca12a_Id", DoubleType(), True),
        StructField("[Geographic_Asset]_is_located_in_[Geographic_Asset]_>_Name", StringType(), True),
        StructField("[Geographic_Asset]_is_located_in_[Geographic_Asset]_>_Full_Name", StringType(), True),
        StructField("[Geographic_Asset]_is_located_in_[Geographic_Asset]_>_Asset_Id", StringType(), True),
        StructField("TargetRelation_01913260-25db-73b9-8478-8652cf1506ca_Id", StringType(), True),
        StructField("[Geographic_Asset]_has_translation_of_[Geographic_Asset]_>_Name", StringType(), True),
        StructField("[Geographic_Asset]_has_translation_of_[Geographic_Asset]_>_Full_Name", StringType(), True),
        StructField("[Geographic_Asset]_has_translation_of_[Geographic_Asset]_>_Asset_Id", StringType(), True),
        StructField("SourceRelation_01910e1c-a59f-77e0-b09f-4d49ad9ca42a_Id", StringType(), True),
        StructField("[Geographic_Asset]_has_state_/_province_/_region_[Geographic_Asset]_>_Name", StringType(), True),
        StructField("[Geographic_Asset]_has_state_/_province_/_region_[Geographic_Asset]_>_Full_Name", StringType(), True),
        StructField("[Geographic_Asset]_has_state_/_province_/_region_[Geographic_Asset]_>_Asset_Id", StringType(), True),
        StructField("SourceRelation_019128cf-7a8c-79f7-8679-4e92520df19b_Id", StringType(), True),
        StructField("[Geographic_Asset]_has_currency_code_[Code_Value]_>_Name", StringType(), True),
        StructField("[Geographic_Asset]_has_currency_code_[Code_Value]_>_Full_Name", StringType(), True),
        StructField("[Geographic_Asset]_has_currency_code_[Code_Value]_>_Asset_Id", StringType(), True),
        StructField("SourceRelation_01918003-729d-774b-8dda-262db3bac102_Id", StringType(), True),
        StructField("Geographic_Type", StringType(), True),
        StructField("Geographic_Type_Id", StringType(), True),
        StructField("dataset_Name", StringType(), True),
        StructField("snapshot_date", StringType(), True)
    ])
    Raw_IPDatasets = spark.readStream.format("parquet").schema(schema).option("path", path).load()
    # display(Raw_IPDatasets)
    return Raw_IPDatasets

# %%
@dlt.table(
    comment="This is just a view of the information to be used in the dashboard",
    name="Raw_states"
)
def Raw_states():
    path = "/Volumes/ds_goc_volumes_dev/external_data/ma-ds-goc-prd-prod-storage-layer-eu-central-1/raw_goc_nosara_lkh/States/*"
    schema = StructType([
        StructField("Full_Name", StringType(), True),
        StructField("Name", StringType(), True),
        StructField("Asset_Id", StringType(), True),
        StructField("Asset_Type_Id", StringType(), True),
        StructField("Asset_Type_Color", StringType(), True),
        StructField("Asset_Type_SymbolType", StringType(), True),
        StructField("Asset_Type_IconCode", DoubleType(), True),
        StructField("Asset_Type_AcronymCode", DoubleType(), True),
        StructField("Asset_Type_Display_Name_Enabled", BooleanType(), True),
        StructField("Domain", StringType(), True),
        StructField("Domain_Id", StringType(), True),
        StructField("[Geographic_Asset]_has_ISO_[Code_Value]_>_Name", StringType(), True),
        StructField("[Geographic_Asset]_has_ISO_[Code_Value]_>_Full_Name", StringType(), True),
        StructField("[Geographic_Asset]_has_ISO_[Code_Value]_>_Asset_Id", StringType(), True),
        StructField("SourceRelation_01910428-5cc8-7375-aa52-eb7381831832_Id", StringType(), True),
        StructField("Description", StringType(), True),
        StructField("Description_Id", StringType(), True),
        StructField("[Geographic_Asset]_geographic_data_provided_by_[Vendor]_>_Name", StringType(), True),
        StructField("[Geographic_Asset]_geographic_data_provided_by_[Vendor]_>_Full_Name", StringType(), True),
        StructField("[Geographic_Asset]_geographic_data_provided_by_[Vendor]_>_Asset_Id", StringType(), True),
        StructField("TargetRelation_0191042a-d029-7597-bd96-78be271c6b80_Id", StringType(), True),
        StructField("[Geographic_Asset]_data_contained_in__[Product]_>_Name", StringType(), True),
        StructField("[Geographic_Asset]_data_contained_in__[Product]_>_Full_Name", StringType(), True),
        StructField("[Geographic_Asset]_data_contained_in__[Product]_>_Asset_Id", StringType(), True),
        StructField("TargetRelation_019104ae-c2cf-75dc-a54d-c0f646956f6e_Id", StringType(), True),
        StructField("[Geographic_Asset]_data_contained_in_[Fourth-Party_Data_Asset]_>_Name", StringType(), True),
        StructField("[Geographic_Asset]_data_contained_in_[Fourth-Party_Data_Asset]_>_Full_Name", StringType(), True),
        StructField("[Geographic_Asset]_data_contained_in_[Fourth-Party_Data_Asset]_>_Asset_Id", StringType(), True),
        StructField("TargetRelation_019104e0-8f88-7c73-ab76-f20e01b77e41_Id", StringType(), True),
        StructField("[Geographic_Asset]_is_a_location_of_[Fourth-Party_Vendor]_>_Name", StringType(), True),
        StructField("[Geographic_Asset]_is_a_location_of_[Fourth-Party_Vendor]_>_Full_Name", StringType(), True),
        StructField("[Geographic_Asset]_is_a_location_of_[Fourth-Party_Vendor]_>_Asset_Id", StringType(), True),
        StructField("SourceRelation_01922e57-da38-70b5-9c9f-40414d452352_Id", StringType(), True),
        StructField("Filing_Requirements", DoubleType(), True),
        StructField("Filing_Requirements_Id", DoubleType(), True),
        StructField("Additional_Considerations", StringType(), True),
        StructField("Additional_Considerations_Id", StringType(), True),
        StructField("[Geographic_Asset]_is_headquarters_to__[Fourth-Party_Vendor]_>_Name", DoubleType(), True),
        StructField("[Geographic_Asset]_is_headquarters_to__[Fourth-Party_Vendor]_>_Full_Name", DoubleType(), True),
        StructField("[Geographic_Asset]_is_headquarters_to__[Fourth-Party_Vendor]_>_Asset_Id", DoubleType(), True),
        StructField("SourceRelation_0192ba77-2e89-7b3a-9730-1451279b82ed_Id", DoubleType(), True),
        StructField("[Geographic_Asset]_main_official_source_of_company_information_[Fourth-Party_Vendor]_>_Name", DoubleType(), True),
        StructField("[Geographic_Asset]_main_official_source_of_company_information_[Fourth-Party_Vendor]_>_Full_Name", DoubleType(), True),
        StructField("[Geographic_Asset]_main_official_source_of_company_information_[Fourth-Party_Vendor]_>_Asset_Id", DoubleType(), True),
        StructField("SourceRelation_0192b4b2-2442-723a-9c30-c9ec6579f796_Id", DoubleType(), True),
        StructField("[Geographic_Asset]_main_provider_of_country_data_is_[Vendor]_>_Name", DoubleType(), True),
        StructField("[Geographic_Asset]_main_provider_of_country_data_is_[Vendor]_>_Full_Name", DoubleType(), True),
        StructField("[Geographic_Asset]_main_provider_of_country_data_is_[Vendor]_>_Asset_Id", DoubleType(), True),
        StructField("TargetRelation_01910e25-7339-7525-a092-3889d1cd7f99_Id", DoubleType(), True),
        StructField("[Geographic_Asset]_main_provider_of_private_company_information_is_[Vendor]_>_Name", DoubleType(), True),
        StructField("[Geographic_Asset]_main_provider_of_private_company_information_is_[Vendor]_>_Full_Name", DoubleType(), True),
        StructField("[Geographic_Asset]_main_provider_of_private_company_information_is_[Vendor]_>_Asset_Id", DoubleType(), True),
        StructField("TargetRelation_01910e28-286f-7001-87ac-27877678ae5a_Id", DoubleType(), True),
        StructField("Country_Data_Overview", DoubleType(), True),
        StructField("Country_Data_Overview_Id", DoubleType(), True),
        StructField("Market_Coverage", DoubleType(), True),
        StructField("Market_Coverage_Id", DoubleType(), True),
        StructField("[Geographic_Asset]_has_translation_of_[Geographic_Asset]_>_Name", StringType(), True),
        StructField("[Geographic_Asset]_has_translation_of_[Geographic_Asset]_>_Full_Name", StringType(), True),
        StructField("[Geographic_Asset]_has_translation_of_[Geographic_Asset]_>_Asset_Id", StringType(), True),
        StructField("SourceRelation_01910e1c-a59f-77e0-b09f-4d49ad9ca42a_Id", StringType(), True),
        StructField("[Geographic_Asset]_is_state_/_province_/_region_within_[Geographic_Asset]_>_Name", StringType(), True),
        StructField("[Geographic_Asset]_is_state_/_province_/_region_within_[Geographic_Asset]_>_Full_Name", StringType(), True),
        StructField("[Geographic_Asset]_is_state_/_province_/_region_within_[Geographic_Asset]_>_Asset_Id", StringType(), True),
        StructField("TargetRelation_019128cf-7a8c-79f7-8679-4e92520df19b_Id", StringType(), True),
        StructField("Note", DoubleType(), True),
        StructField("Note_Id", DoubleType(), True),
        StructField("Region_Code", DoubleType(), True),
        StructField("Region_Code_Id", DoubleType(), True),
        StructField("[Geographic_Asset]_has_currency_code_[Code_Value]_>_Name", DoubleType(), True),
        StructField("[Geographic_Asset]_has_currency_code_[Code_Value]_>_Full_Name", DoubleType(), True),
        StructField("[Geographic_Asset]_has_currency_code_[Code_Value]_>_Asset_Id", DoubleType(), True),
        StructField("SourceRelation_01918003-729d-774b-8dda-262db3bac102_Id", DoubleType(), True),
        StructField("dataset_Name", StringType(), True),
        StructField("snapshot_date", StringType(), True)
    ])
    Raw_states = spark.readStream.format("parquet").schema(schema).option("path", path).load()
    # display(Raw_states)
    return Raw_states

# %%
@dlt.table(
    comment="This is just a view of the information to be used in the dashboard",
    name="Raw_IP_Reference_Codes"
)
def Raw_IP_Reference_Codes():
    path = "/Volumes/ds_goc_volumes_dev/external_data/ma-ds-goc-prd-prod-storage-layer-eu-central-1/raw_goc_nosara_lkh/IP_Reference_Codes/*"
    schema = StructType([
        StructField("Full_Name", StringType(), True),
        StructField("Name", StringType(), True),
        StructField("Asset_Id", StringType(), True),
        StructField("Asset_Type_Id", StringType(), True),
        StructField("Asset_Type_Color", StringType(), True),
        StructField("Asset_Type_SymbolType", StringType(), True),
        StructField("Asset_Type_IconCode", DoubleType(), True),
        StructField("Asset_Type_AcronymCode", StringType(), True),
        StructField("Asset_Type_Display_Name_Enabled", BooleanType(), True),
        StructField("Domain", StringType(), True),
        StructField("Domain_Id", StringType(), True),
        StructField("Status", StringType(), True),
        StructField("Status_Id", StringType(), True),
        StructField("Status_Is_System", BooleanType(), True),
        StructField("[Code_Value]_identifies_[Vendor]_>_Name", StringType(), True),
        StructField("[Code_Value]_identifies_[Vendor]_>_Full_Name", StringType(), True),
        StructField("[Code_Value]_identifies_[Vendor]_>_Asset_Id", StringType(), True),
        StructField("SourceRelation_c319bb49-8805-4b07-be97-dc5ae7b0ba89_Id", StringType(), True),
        StructField("[Code_Value]_identifies_[Product]_>_Name", StringType(), True),
        StructField("[Code_Value]_identifies_[Product]_>_Full_Name", StringType(), True),
        StructField("[Code_Value]_identifies_[Product]_>_Asset_Id", StringType(), True),
        StructField("TargetRelation_795e9c10-a3f2-4602-b35e-649600497804_Id", StringType(), True),
        StructField("Description", StringType(), True),
        StructField("Description_Id", StringType(), True),
        StructField("[Code_Value]_groups_[Code_Value]_>_Name", DoubleType(), True),
        StructField("[Code_Value]_groups_[Code_Value]_>_Full_Name", DoubleType(), True),
        StructField("[Code_Value]_groups_[Code_Value]_>_Asset_Id", StringType(), True),
        StructField("SourceRelation_00000000-0000-0000-0000-000000007022_Id", StringType(), True),
        StructField("Additional_Metadata", DoubleType(), True),
        StructField("Additional_Metadata_Id", DoubleType(), True),
        StructField("Available_in_which_products/platforms", StringType(), True),
        StructField("Available_in_which_products/platforms_Id", StringType(), True),
        StructField("ID", StringType(), True),
        StructField("ID_Id", StringType(), True),
        StructField("dataset_Name", StringType(), True),
        StructField("snapshot_date", StringType(), True)
    ])
    Raw_IP_Reference_Codes = spark.readStream.format("parquet").schema(schema).option("path", path).load()
    # display(Raw_IP_Reference_Codes)
    return Raw_IP_Reference_Codes

# %%
@dlt.table(
    comment="This is just a view of the information to be used in the dashboard",
    name="Raw_SourceCodesforDatasets"
)
def Raw_Source_Codes_for_Datasets():
    path = "/Volumes/ds_goc_volumes_dev/external_data/ma-ds-goc-prd-prod-storage-layer-eu-central-1/raw_goc_nosara_lkh/Source_Codes_for_Datasets/*"
    schema = StructType([
        StructField("Full_Name", LongType(), True),
        StructField("Name", LongType(), True),
        StructField("Asset_Id", StringType(), True),
        StructField("Asset_Type_Id", StringType(), True),
        StructField("Asset_Type_Color", StringType(), True),
        StructField("Asset_Type_SymbolType", StringType(), True),
        StructField("Asset_Type_IconCode", DoubleType(), True),
        StructField("Asset_Type_AcronymCode", StringType(), True),
        StructField("Asset_Type_Display_Name_Enabled", BooleanType(), True),
        StructField("Domain", StringType(), True),
        StructField("Domain_Id", StringType(), True),
        StructField("Status", StringType(), True),
        StructField("Status_Id", StringType(), True),
        StructField("Status_Is_System", BooleanType(), True),
        StructField("[Code_Value]_identifies_[Product]_>_Name", StringType(), True),
        StructField("[Code_Value]_identifies_[Product]_>_Full_Name", StringType(), True),
        StructField("[Code_Value]_identifies_[Product]_>_Asset_Id", StringType(), True),
        StructField("TargetRelation_795e9c10-a3f2-4602-b35e-649600497804_Id", StringType(), True),
        StructField("[Code_Value]_identifies_[Vendor]_>_Name", StringType(), True),
        StructField("[Code_Value]_identifies_[Vendor]_>_Full_Name", StringType(), True),
        StructField("[Code_Value]_identifies_[Vendor]_>_Asset_Id", StringType(), True),
        StructField("SourceRelation_c319bb49-8805-4b07-be97-dc5ae7b0ba89_Id", StringType(), True),
        StructField("Description", StringType(), True),
        StructField("Description_Id", StringType(), True),
        StructField("[Code_Value]_grouped_by_[Code_Value]_>_Name", StringType(), True),
        StructField("[Code_Value]_grouped_by_[Code_Value]_>_Full_Name", StringType(), True),
        StructField("[Code_Value]_grouped_by_[Code_Value]_>_Asset_Id", StringType(), True),
        StructField("TargetRelation_00000000-0000-0000-0000-000000007022_Id", StringType(), True),
        StructField("Available_in_which_products/platforms", StringType(), True),
        StructField("Available_in_which_products/platforms_Id", StringType(), True),
        StructField("ID", StringType(), True),
        StructField("ID_Id", StringType(), True),
        StructField("Additional_Metadata", StringType(), True),
        StructField("Additional_Metadata_Id", StringType(), True),
        StructField("Note", DoubleType(), True),
        StructField("Note_Id", DoubleType(), True),
        StructField("dataset_Name", StringType(), True),
        StructField("snapshot_date", StringType(), True)
    ])
    Raw_Source_Codes_for_Datasets = spark.readStream.format("parquet").schema(schema).option("path", path).load()
    # display(Raw_Source_Codes_for_Datasets)
    return Raw_Source_Codes_for_Datasets

# %%
import dlt
from pyspark.sql.types import StringType, BooleanType, StructType, StructField
from pyspark.sql.functions import col

@dlt.table(
    comment="This is just a view of the information to be used in the dashboard",
    name="Raw_IP_Original_Source_By_Data_Type"
)
def Raw_IP_Original_Source_By_Data_Type():
    path = "/Volumes/ds_goc_volumes_dev/external_data/ma-ds-goc-prd-prod-storage-layer-eu-central-1/raw_goc_nosara_lkh/IP_Original_Source_By_Data_Type_Fourth_Party_Datasets/*"
    
    # Infer schema from existing files
    static_df = spark.read.format("parquet").load(path)
    inferred_schema = static_df.schema
    
    # Define the schema explicitly
    schema = StructType([
        StructField("[Fourth-Party_Data_Asset]_contains_data_on_[Geographic_Asset]_>_Name", StringType(), True),
        StructField("[Fourth-Party_Data_Asset]_contains_data_on_[Geographic_Asset]_>_Full_Name", StringType(), True),
        StructField("[Fourth-Party_Data_Asset]_contains_data_on_[Geographic_Asset]_>_Asset_Id", StringType(), True),
        StructField("SourceRelation_019104e0-8f88-7c73-ab76-f20e01b77e41_Id", StringType(), True),
        StructField("[Fourth-Party_Data_Asset]_has_ISO_[Code_Value]_>_Name", StringType(), True),
        StructField("[Fourth-Party_Data_Asset]_has_ISO_[Code_Value]_>_Full_Name", StringType(), True),
        StructField("[Fourth-Party_Data_Asset]_has_ISO_[Code_Value]_>_Asset_Id", StringType(), True),
        StructField("SourceRelation_018f815f-936b-74ab-8774-fdaef3959f89_Id", StringType(), True),
        StructField("Full_Name", StringType(), True),
        StructField("Name", StringType(), True),
        StructField("Asset_Id", StringType(), True),
        StructField("Asset_Type_Id", StringType(), True),
        StructField("Asset_Type_Color", StringType(), True),
        StructField("Asset_Type_SymbolType", StringType(), True),
        StructField("Asset_Type_IconCode", StringType(), True),
        StructField("Asset_Type_AcronymCode", StringType(), True),
        StructField("Asset_Type_Display_Name_Enabled", BooleanType(), True),
        StructField("Domain", StringType(), True),
        StructField("Domain_Id", StringType(), True),
        StructField("Status", StringType(), True),
        StructField("Status_Id", StringType(), True),
        StructField("Status_Is_System", BooleanType(), True),
        StructField("Description", StringType(), True),
        StructField("Description_Id", StringType(), True),
        StructField("Type", StringType(), True),
        StructField("Type_Id", StringType(), True),
        StructField("[Fourth-Party_Data_Asset]_supplies_data_to_[Vendor]_>_Name", StringType(), True),
        StructField("[Fourth-Party_Data_Asset]_supplies_data_to_[Vendor]_>_Full_Name", StringType(), True),
        StructField("[Fourth-Party_Data_Asset]_supplies_data_to_[Vendor]_>_Asset_Id", StringType(), True),
        StructField("SourceRelation_018f815d-6fc5-78b6-887d-11c8ffe3c31a_Id", StringType(), True),
        StructField("[Fourth-Party_Data_Asset]_receives_data_from__[Fourth-Party_Vendor]_>_Name", StringType(), True),
        StructField("[Fourth-Party_Data_Asset]_receives_data_from__[Fourth-Party_Vendor]_>_Full_Name", StringType(), True),
        StructField("[Fourth-Party_Data_Asset]_receives_data_from__[Fourth-Party_Vendor]_>_Asset_Id", StringType(), True),
        StructField("TargetRelation_018f815e-6432-768e-a385-80e6a4c645fb_Id", StringType(), True),
        StructField("[Fourth-Party_Data_Asset]_Feeds_[Product]_>_Name", StringType(), True),
        StructField("[Fourth-Party_Data_Asset]_Feeds_[Product]_>_Full_Name", StringType(), True),
        StructField("[Fourth-Party_Data_Asset]_Feeds_[Product]_>_Asset_Id", StringType(), True),
        StructField("SourceRelation_0192ba67-15b2-7ee5-9549-d735bf3aac38_Id", StringType(), True),
        StructField("[Fourth-Party_Data_Asset]_is_classified_by_[Business_Dimension]_>_Name", StringType(), True),
        StructField("[Fourth-Party_Data_Asset]_is_classified_by_[Business_Dimension]_>_Full_Name", StringType(), True),
        StructField("[Fourth-Party_Data_Asset]_is_classified_by_[Business_Dimension]_>_Asset_Id", StringType(), True),
        StructField("TargetRelation_018f8169-c99c-7eb6-ad0f-46e9b9664610_Id", StringType(), True),
        StructField("IP_Data_Type_Delivery_Frequency_to_Moody's", StringType(), True),
        StructField("IP_Data_Type_Delivery_Frequency_to_Moody's_Id", StringType(), True),
        StructField("IP_Data_Type_Update_Frequency_from_their_Source", StringType(), True),
        StructField("IP_Data_Type_Update_Frequency_from_their_Source_Id", StringType(), True),
        StructField("Original_Source_Data_Frequency", StringType(), True),
        StructField("Original_Source_Data_Frequency_Id", StringType(), True),
        StructField("Name_Displayed_in_ORBIS", StringType(), True),
        StructField("Name_Displayed_in_ORBIS_Id", StringType(), True),
        StructField("dataset_Name", StringType(), True),
        StructField("snapshot_date", StringType(), True)
    ])
    
    # Read the data with the defined schema and enable schema evolution
    df = spark.readStream.format("parquet") \
        .schema(schema) \
        .option("mergeSchema", "true") \
        .option("path", path) \
        .load()   
    # display(df)
    return df

# %%
@dlt.table(
    comment="This is just a view of the information to be used in the dashboard",
    name="Raw_Sources_used_by_IPs"
)
def Raw_Sources_used_by_IPs():
    path = "/Volumes/ds_goc_volumes_dev/external_data/ma-ds-goc-prd-prod-storage-layer-eu-central-1/raw_goc_nosara_lkh/Sources_used_by_IPs/*"
    schema = StructType([
        StructField("Original_Name", StringType(), True),
        StructField("Original_Name_Id", StringType(), True),
        StructField("Full_Name", StringType(), True),
        StructField("Name", StringType(), True),
        StructField("Asset_Id", StringType(), True),
        StructField("Asset_Type_Id", StringType(), True),
        StructField("Asset_Type_Color", StringType(), True),
        StructField("Asset_Type_SymbolType", StringType(), True),
        StructField("Asset_Type_IconCode", DoubleType(), True),
        StructField("Asset_Type_AcronymCode", DoubleType(), True),
        StructField("Asset_Type_Display_Name_Enabled", BooleanType(), True),
        StructField("Domain", StringType(), True),
        StructField("Domain_Id", StringType(), True),
        StructField("Alias", StringType(), True),
        StructField("Alias_Id", StringType(), True),
        StructField("[Fourth-Party_Vendor]_supplies_data_on_entities_in_ISO_[Code_Value]_>_Name", StringType(), True),
        StructField("[Fourth-Party_Vendor]_supplies_data_on_entities_in_ISO_[Code_Value]_>_Full_Name", StringType(), True),
        StructField("[Fourth-Party_Vendor]_supplies_data_on_entities_in_ISO_[Code_Value]_>_Asset_Id", StringType(), True),
        StructField("SourceRelation_018f81a2-8312-79ad-994f-622734ba870e_Id", StringType(), True),
        StructField("[Fourth-Party_Vendor]_operates_in_[Geographic_Asset]_>_Name", StringType(), True),
        StructField("[Fourth-Party_Vendor]_operates_in_[Geographic_Asset]_>_Full_Name", StringType(), True),
        StructField("[Fourth-Party_Vendor]_operates_in_[Geographic_Asset]_>_Asset_Id", StringType(), True),
        StructField("TargetRelation_01922e57-da38-70b5-9c9f-40414d452352_Id", StringType(), True),
        StructField("Description", StringType(), True),
        StructField("Description_Id", StringType(), True),
        StructField("URL", StringType(), True),
        StructField("URL_Id", StringType(), True),
        StructField("[Fourth-Party_Vendor]_is_authoritative_source_of_[Vendor]_>_Name", StringType(), True),
        StructField("[Fourth-Party_Vendor]_is_authoritative_source_of_[Vendor]_>_Full_Name", StringType(), True),
        StructField("[Fourth-Party_Vendor]_is_authoritative_source_of_[Vendor]_>_Asset_Id", StringType(), True),
        StructField("SourceRelation_018f81ac-75bf-706a-9472-affabbaa7334_Id", StringType(), True),
        StructField("[Fourth-Party_Vendor]_is_main_source_of_company_information_[Geographic_Asset]_>_Name", StringType(), True),
        StructField("[Fourth-Party_Vendor]_is_main_source_of_company_information_[Geographic_Asset]_>_Full_Name", StringType(), True),
        StructField("[Fourth-Party_Vendor]_is_main_source_of_company_information_[Geographic_Asset]_>_Asset_Id", StringType(), True),
        StructField("TargetRelation_0192b4b2-2442-723a-9c30-c9ec6579f796_Id", StringType(), True),
        StructField("[Fourth-Party_Vendor]_supplies_data_to__[Fourth-Party_Data_Asset]_>_Name", StringType(), True),
        StructField("[Fourth-Party_Vendor]_supplies_data_to__[Fourth-Party_Data_Asset]_>_Full_Name", StringType(), True),
        StructField("[Fourth-Party_Vendor]_supplies_data_to__[Fourth-Party_Data_Asset]_>_Asset_Id", StringType(), True),
        StructField("SourceRelation_018f815e-6432-768e-a385-80e6a4c645fb_Id", StringType(), True),
        StructField("Registry_publication_latency", StringType(), True),
        StructField("Registry_publication_latency_Id", StringType(), True),
        StructField("Update_Frequency", DoubleType(), True),
        StructField("Update_Frequency_Id", DoubleType(), True),
        StructField("Note", StringType(), True),
        StructField("Note_Id", StringType(), True),
        StructField("Background", DoubleType(), True),
        StructField("Background_Id", DoubleType(), True),
        StructField("Last_Review_Date", DoubleType(), True),
        StructField("Last_Review_Date_Id", DoubleType(), True),
        StructField("Update_Frequency_Notes", StringType(), True),
        StructField("Update_Frequency_Notes_Id", StringType(), True),
        StructField("dataset_Name", StringType(), True),
        StructField("snapshot_date", StringType(), True)
    ])
    Raw_Sources_used_by_IPs = spark.readStream.format("parquet").schema(schema).option("path", path).load()
    # display(Raw_Sources_used_by_IPs)
    return Raw_Sources_used_by_IPs
